# %% [markdown]
# <a href="https://colab.research.google.com/github/JustynaD00/Project-2/blob/main/Rasa_Chatbot_Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Creating Rasa chatbot for travel and tourims industry**

# %%
# Installing the latest version of Rasa
# !pip install rasa==3.4.5
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 824.0/824.0 kB 9.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 45.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.6/124.6 kB 14.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.7/199.7 kB 20.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 40.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 13.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 66.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 59.9 MB/s eta 0:00:00
# ...

# %%
# !pip install -U ipython
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.2/809.2 kB 4.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.1/386.1 kB 9.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 3.0.28
#     Uninstalling prompt-toolkit-3.0.28:
#       Successfully uninstalled prompt-toolkit-3.0.28
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.34.0
#     Uninstalling ipython-7.34.0:
#       Successfully uninstalled ipython-7.34.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 8.20.0 which is incompatible.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.4.51 which is incompatible.
# ...

# %% [markdown]
# **Click on above "RESTART RUNTIME" button, this is to make sure that the code will work as it should**
#
# ![button.PNG](data:image/png;base64,...)

# %%
# !pip install websockets==10.0
# !pip install websocket-client
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.8/81.8 kB 884.9 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for websockets: filename=websockets-10.0-cp310-cp310-linux_x86_64.whl size=103014 sha256=3d1afdfe5bc98af4e81d49c7ab1aab5b59b42bf6207df1e8c9334ed2ca0bceab
#   Stored in directory: /root/.cache/pip/wheels/d5/56/64/2ecbd74736716d6bba72d533296fac530c4530a84f932bcd81
# Successfully built websockets
# ...
#   Attempting uninstall: websockets
#     Found existing installation: websockets 12.0
#     Uninstalling websockets-12.0:
#       Successfully uninstalled websockets-12.0
# ...

# %%
# Download spacy for the NLP pipeline tasks.
# !python -m spacy download en_core_web_sm
# Out:
# 2024-01-12 21:51:25.350818: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-12 21:51:25.350891: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2024-01-12 21:51:29.461691: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-12 21:51:29.461778: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# ...

# %%
# This is  used to build information extraction or natural language understanding systems, or to pre-process text for deep learning.
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
# Running asynchronous Rasa code in Jupyter Notebooks requires an extra requirement, since Jupyter Notebooks already run on event loops.
# Install this requirement in the command line before launching jupyter:

# !pip install nest_asyncio==1.3.3
# Out:
# ...
#   Attempting uninstall: nest_asyncio
#     Found existing installation: nest-asyncio 1.5.8
#     Uninstalling nest-asyncio-1.5.8:
#       Successfully uninstalled nest-asyncio-1.5.8
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# nbclassic 1.0.0 requires nest-asyncio>=1.5, but you have nest-asyncio 1.3.3 which is incompatible.
# notebook 6.5.5 requires nest-asyncio>=1.5, but you have nest-asyncio 1.3.3 which is incompatible.
# ...

# %%
import os
import rasa
import nest_asyncio

nest_asyncio.apply()
print("Event loop ready.")
# Out:
# Event loop ready.

# %%
# Prepare for creating a project space for the Cruise Chatbot
from rasa.cli.scaffold import create_initial_project

# %%
# Assign a name to the project
project = "cruise-chatbot"
create_initial_project(project)

# %%
# move into project directory and show files
os.chdir(project)
print(os.listdir("."))
# Out:
# ['data', 'endpoints.yml', 'credentials.yml', 'actions', 'config.yml', 'domain.yml', 'tests']

# %%
# To train the model,by passing in the paths to the rasa.train function.
# Note that the training files are passed as a list.
# When training has finished, rasa.train returns the path where the trained model has been saved.

config = "config.yml"
training_files = "data/"
domain = "domain.yml"
output = "models/"
print(config, training_files, domain, output)
# Out:
# config.yml data/ domain.yml models/

# %% [markdown]
# ### Sometime it may not run on first go. So, try to execute below line 3 time and it work fine. It is bug in rasa.

# %%
# Train a ML model

model_path = rasa.train(domain, config, [training_files], output)
print(model_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/rasa/engine/caching.py:152: MovedIn20Warning: Deprecated API features detected! These feature(s) are not compatible with SQLAlchemy 2.0. To prevent incompatible upgrades prior to updating applications, ensure requirements files are pinned to "sqlalchemy<2.0". Set environment variable SQLALCHEMY_WARN_20=1 to show all deprecation warnings.  Set environment variable SQLALCHEMY_SILENCE_UBER_WARNING=1 to silence this message. (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base: DeclarativeMeta = declarative_base()
# <frozen importlib._bootstrap>:283: DeprecationWarning: the load_module() method is deprecated and slated for removal in Python 3.12; use exec_module() instead
# (0lqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqk(B
# (0x(B Rasa Open Source reports anonymous usage telemetry to help improve the product (0x(B
# ...

# %%
# Chat with your assistant#
# To start chatting to an assistant, we call the chat function, passing in the path to your saved model.
# Setting endpoints to None as no custom action required

from rasa.jupyter import chat

#endpoints = 'endpoints.yml'

endpoints = None

# %%
# Starting the conversation
chat(model_path.model, endpoints)
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradients/cond_grad/Identity_1:0", shape=(None,), dtype=int64), values=Tensor("gradients/cond_grad/Identity:0", shape=(None,), dtype=float32), dense_shape=Tensor("gradients/cond_grad/Identity_2:0", shape=(1,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradients/cond_1_grad/Identity_1:0", shape=(None,), dtype=int64), values=Tensor("gradients/cond_1_grad/Identity:0", shape=(None,), dtype=float32), dense_shape=Tensor("gradients/cond_1_grad/Identity_2:0", shape=(1,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# ...

# %% [markdown]
# ## **CRUISE CHATBOT - TRAINING DATA **
#
# Creating the Stories.md, NLU.md and Domain.yml

# %%
# %%writefile data/stories.yml
#
#
# version: "3.1"
#
# stories:
#
# - story: booking a booking cruise 1 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_inform_of_reg_process
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
#
# - story: booking a booking cruise 2 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1weekinterior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1weekinterior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
#
# - story: booking a booking cruise 1 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
#
# - story: booking a booking cruise 1 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
#
# - story: booking a booking cruise month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
# - story: booking a booking cruise 4 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
#
# - story: booking a booking cruise 1 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
# Out:
# Overwriting data/stories.yml

# %%
# %%writefile data/stories.yml
#
#
# version: "3.1"
#
# stories:
#
# - story: booking a booking cruise 1 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_inform_of_reg_process
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
#
# - story: booking a booking cruise 2 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1weekinterior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1weekinterior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
#
# - story: booking a booking cruise 1 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
#
# - story: booking a booking cruise 1 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
#
# - story: booking a booking cruise month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
# - story: booking a booking cruise 4 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
#
# - story: booking a booking cruise 1 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
# Out:
# Overwriting data/stories.yml

# %%
# %%writefile data/stories.yml
#
#
# version: "3.1"
#
# stories:
#
# - story: booking a booking cruise 1 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_inform_of_reg_process
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
#
# - story: booking a booking cruise 2 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1weekinterior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1weekinterior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
#
# - story: booking a booking cruise 1 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
#
# - story: booking a booking cruise 1 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
#
# - story: booking a booking cruise month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
# - story: booking a booking cruise 4 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
#
# - story: booking a booking cruise 1 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
# Out:
# Overwriting data/stories.yml

# %%
# %%writefile data/stories.yml
#
#
# version: "3.1"
#
# stories:
#
# - story: booking a booking cruise 1 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_inform_of_reg_process
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
#
# - story: booking a booking cruise 2 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1weekinterior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1weekinterior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
#
# - story: booking a booking cruise 1 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
#
# - story: booking a booking cruise 1 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
#
# - story: booking a booking cruise month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
# - story: booking a booking cruise 4 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
#
# - story: booking a booking cruise 1 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
# Out:
# Overwriting data/stories.yml

# %%
# %%writefile data/stories.yml
#
#
# version: "3.1"
#
# stories:
#
# - story: booking a booking cruise 1 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_inform_of_reg_process
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
#
# - story: booking a booking cruise 2 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1weekinterior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1weekinterior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
#
# - story: booking a booking cruise 1 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
#
# - story: booking a booking cruise 1 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
#
# - story: booking a booking cruise month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
# - story: booking a booking cruise 4 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
#
# - story: booking a booking cruise 1 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 1 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 2 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 3 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 4 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 5 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 6 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 7 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 8 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 9 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
#
# - story: booking a booking cruise 10 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_pers_info
# Out:
# Overwriting data/stories.yml

# %%
# %%writefile data/stories.yml
#
#
# version: "3.1"
#
# stories:
#
# - story: booking a booking cruise 1 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_inform_of_reg_process
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
#
# - story: booking a booking cruise 2 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1weekinterior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1weekinterior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 1week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_1week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
#
# - story: booking a booking cruise 1 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
#
# - story: booking a booking cruise 1 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 2week suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_2week
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 month interior and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
#
# - story: booking a booking cruise month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 month interior and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 month interior and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_interior
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 month outsideview and 2double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 month outsideview and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 month outsideview and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_outsideview
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 month balcony and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 month balcony and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 month balcony and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_balcony
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
#
# - story: booking a booking cruise 1 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 month suite and double
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_2double
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 month suite and king
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_king
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 1 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_1
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 2 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_2
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 3 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_3
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 4 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_4
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 5 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_5
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 6 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_6
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 7 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_7
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 8 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_8
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 9 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_9
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking a booking cruise 10 month suite and family
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: Booking_cruise
#   - action: utter_Conf_destination
#   - intent: Conf_destination_10
#   - action: utter_Conf_duration
#   - intent: Conf_duration_month
#   - action: utter_room_book
#   - intent: room_book_suite
#   - action: utter_bed_conf
#   - intent: bed_conf_family
#   - action: utter_confirm
#   - intent: affirm
#   - action: utter_info_name
#   - intent: confirm_name
#   - action: utter_info_email
#   - intent: confirm_email
#   - action: utter_upload_picture
#   - intent: confirm_upload
#   - action: utter_thatseverything
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking cancellation
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: cancel_booking
#   - action: utter_cancellation_info
#   - intent: thankyou
#   - action: utter_anythingelse
#   - intent: deny
#   - action: utter_goodbye
#
# - story: booking cancellation with booking
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: cancel_booking
#   - action: utter_cancellation_info
#   - intent: thankyou
#   - action: utter_anythingelse
#   - intent: Booking_cruise
# Out:
# Overwriting data/stories.yml

# %%
# %%writefile data/nlu.yml
#
# version: "3.1"
#
# nlu:
# - intent: greet
#   examples: |
#     - hey
#     - hello
#     - hi
#     - hello there
#     - good morning
#     - good evening
#     - moin
#     - hey there
#     - let's go
#     - hey dude
#     - goodmorning
#     - goodevening
#     - good afternoon
#
# - intent: goodbye
#   examples: |
#     - cu
#     - good by
#     - cee you later
#     - good night
#     - bye
#     - goodbye
#     - have a nice day
#     - see you around
#     - bye bye
#     - see you later
#
# - intent: affirm
#   examples: |
#     - yes
#     - y
#     - indeed
#     - of course
#     - that sounds good
#     - correct
#
# - intent: thankyou
#   examples: |
#     - thank you
#     - thanks
#     - tia
#     - cheers
#
# - intent: deny
#   examples: |
#     - no
#     - n
#     - never
#     - I don't think so
#     - don't like that
#     - no way
#     - not really
#
# - intent: bot_challenge
#   examples: |
#     - are you a bot?
#     - are you a human?
#     - am I talking to a bot?
#     - am I talking to a human?
#
# - intent: Booking_cruise
#   examples: |
#    - I would like to book a cruise
#    - I want to go on a cruise
#    - Book a cruise
#    - Can I book a cruise?
#
# - intent: Conf_destination_1
#   examples: |
#    - I want to go to France
#    - France
#    - I want to take a cruise to France
#
# - intent: Conf_destination_2
#   examples: |
#    - I want to go to Norway
#    - Norway
#    - I want to take a cruise to Norway
#
# - intent: Conf_destination_3
#   examples: |
#    - I want to go to Croatia
#    - Croatia
#    - I want to take a cruise to Croatia
#
# - intent: Conf_destination_4
#   examples: |
#    - I want to go to Greece
#    - Greece
#    - I want to take a cruise to Greece
#
# - intent: Conf_destination_5
#   examples: |
#    - I want to go to Thailand
#    - Thailand
#    - I want to take a cruise to Thailand
#
# - intent: Conf_destination_6
#   examples: |
#    - I want to go to China
#    - China
#    - I want to take a cruise to China
#
# - intent: Conf_destination_7
#   examples: |
#    - I want to go to Japan
#    - Japan
#    - I want to take a cruise to Japan
#
# - intent: Conf_destination_8
#   examples: |
#    - I want to go to Florida
#    - Florida
#    - I want to take a cruise to Florida
#
# - intent: Conf_destination_9
#   examples: |
#    - I want to go to Hawaii
#    - Hawaii
#    - I want to take a cruise to Hawaii
#
# - intent: Conf_destination_10
#   examples: |
#    - I want to go to Canada
#    - Canada
#    - I want to take a cruise to Canada
#
# - intent: Conf_duration_month
#   examples: |
#    - I want to go for a month
#    - I want to travel for a month
#    - one month
#    - for one month please
#
# - intent: Conf_duration_1week
#   examples: |
#    - I want to go for a week
#    - I want to travel for a week
#    - one week
#    - a week
#    - for a week please
#
# - intent: Conf_duration_2week
#   examples: |
#    - I want to go for 2 weeks
#    - I want to travel for two weeks
#    - 2 weeks
#    - two weeks
#    - for 2 weeks
#
#
# - intent: room_book_interior
#   examples: |
#    - I want an interior room
#    - I would like to stay in a interior
#    - interior room please
#    - interior
#    - I want an interior room
#    - Interior room will be just fine
#
# - intent: room_book_outsideview
#   examples: |
#    - I want a room with outside view
#    - I would like to stay in outside view room please
#    - outside view room please
#    - outside view
#    - room with outside view
#    - I want an outisdie view
#
# - intent: room_book_balcony
#   examples: |
#    - I want a room with a balcony
#    - I would like to stay in a balcony room please
#    - balcony room please
#    - balcony
#    - room with a balcony please
#    - I want a balcony in my room
#
# - intent: room_book_suite
#   examples: |
#    - I want a suite
#    - I would like to stay in a suite room please
#    - suite please
#    - suite
#    - suite room would be great
#    - I would like  a suite room
#    - I want a suite
#
# - intent: bed_conf_family
#   examples: |
#    - I would like a family room please
#    - Family room
#    - I need a family room
#    - The family one
#
# - intent: bed_conf_king
#   examples: |
#    - I would like a king size bed
#    - I need a king
#    - King Size
#
# - intent: bed_conf_2double
#   examples: |
#    - I need two beds
#    - The double beds option
#    - Two double beds please
#
# - intent: confirm_name
#   examples:  |
#    - My name is Justyna Dobersztajn
#    - My full name is Will Smith
#    - My first name is Lydia and my last name is Brown
#    - Thomas Townsend
#
# - intent: confirm_email
#   examples:  |
#    - jdobersz@bradford.ac.uk
#    - domain99@gmail.com
#    - uswat00@outlook.co.uk
#    - my email address is shabbir111@yahoo.com
#
# - intent: confirm_upload
#   examples:  |
#    - image uploaded
#    - image upload complete
#
# - intent: cancel_booking
#   examples:  |
#    - I would like to cancel my booking
#    - Booking cancellation
#    - Policy for cancelling a booking
# Out:
# Overwriting data/nlu.yml

# %%
# %%writefile domain.yml
#
#
# version: "3.1"
#
#
# intents:
#   - greet
#   - goodbye
#   - affirm
#   - deny
#   - bot_challenge
#   - Booking_cruise
#   - Conf_destination_1
#   - Conf_destination_2
#   - Conf_destination_3
#   - Conf_destination_4
#   - Conf_destination_5
#   - Conf_destination_6
#   - Conf_destination_7
#   - Conf_destination_8
#   - Conf_destination_9
#   - Conf_destination_10
#   - Conf_duration_1week
#   - Conf_duration_2week
#   - Conf_duration_month
#   - room_book_interior
#   - room_book_outsideview
#   - room_book_balcony
#   - room_book_suite
#   - bed_conf_2double
#   - bed_conf_family
#   - bed_conf_king
#   - confirm_email
#   - confirm_name
#   - confirm_upload
#   - cancel_booking
#   - thankyou
#
# responses:
#
#   utter_greet:
#   - text: "Hello! Welcome to Royal Caribbean!
#   \n\n
#   My name is SunShine, how may I assist you today?"
#
#   utter_did_that_help:
#   - text: "Did that help you?"
#
#   utter_happy:
#   - text: " Glad you're okay "
#
#   utter_start_again:
#   - text: "Would you like to start the booking again?"
#
#   utter_goodbye:
#   - text: "Thank you and goodbye for now."
#
#   utter_iamabot:
#   - text: "I am a bot, powered by Rasa."
#
#   utter_anythingelse:
#   - text: "Is there anything else I can help with?"
#
#   utter_Conf_destination:
#   - text: "Amazing, lets get you started! Firstly, where would you like to go?
# \n\n
# Here are some of our popular destinations:
# \n\n
# Europe:
# \n\n
#       1) France
# \n\n
#       2) Norway
# \n\n
#       3) Croatia
# \n\n
#       4) Greece
# \n\n
#
# Asia:
# \n\n
#       1) Thailand
# \n\n
#       2) China
# \n\n
#       3) Japan
# \n\n
#
#
# North America:
# \n\n
#       1) Florida
# \n\n
#       2) Hawaii
# \n\n
#       3) Canada
#
# \n\n
#
# Or go to the following link to see the full list of our destinations: https://www.royalcaribbean.com/gbr/en/cruise-destinations?
# "
#   utter_Conf_duration:
#   - text: "Amazing, and how long do you want to travel for?
#   You can pick from the following:
#
#   1 week
#
#   2 weeks
#
#   A month "
#
#   utter_room_book:
#   - text: "Great! And what sort of room would you like?
#
#   We offer the following options:
#   \n\n
#   \n\n
#   Interior- \n\n
#   Our Interior staterooms include a wide array of amenities for your whole family to enjoy.
#   \n\n
#   \n\n
#   Outside view - \n\n
#   Savour the seaside and snapshots of landscapes from shore to shore.
#   \n\n
#   \n\n
#   Balcony - \n\n
#   Claim your slice of paradise with balcony views just outside your door.
#   \n\n
#   \n\n
#   Suite - \n\n
#   Enjoy expansive accommodation that takes luxury to the next level.
#   "
#
#   utter_bed_conf:
#   - text: "And how many beds do you need? We offer different options!
#   \n\n
#
#   King size bed - one king size bed, perfect for a couple or a solo traveller!
#   \n\n
#
#   Double room - 2 double beds, ideal for friends and families!
#   \n\n
#
#   Family room - Includes 1 king size bed and 4 single beds,
#   with an extra double sofa bed
#   "
#
#   utter_pers_info:
#   - text: "please confirm you details"
#
#   utter_confirm:
#   - text: "Great! We have found you several offers starting from £300!
# \n\n
#   Would you like to proceed with the registration to book your dream cruise?"
#
#   utter_inform_of_reg_process:
#   - text: "We will need the following:
#
#   Your full name, email address and a picture of yourself.
#
#   Once we have these information we will send you an email with the offers and
#   the log in details so that you can finish the booking and make the payment.
#
#   To view terms and coditions and information on how we may use your information
#   visit:
#
# https://www.royalcaribbean.com/gbr/en/terms-and-conditions/digital-terms-of-use-and-end-user-license-agreement
#
#   If you have all these details and would like to continue please say 'yes'
#   "
#
#   utter_info_name:
#   - text: "Brilliant, what is your full name please?"
#
#   utter_info_email:
#   - text: "Thank you, and what is your email address please?"
#
#   utter_upload_picture:
#   - text: "Lastly, please take a well-lit selfie facing forward with a neutral
#   expression, ensuring your entire face is visible and upload it to the link below;
# \n\n
#   Before you upload the picture please make sure your image name is your firstname_lastname :
#   https://uswatyusuf.github.io/Project2A23/
# \n\n
#   Once you have uploaded the image please say - image upload complete "
#
#   utter_thatseverything:
#   - text: " Thank you. That is everything. You should receieve an email from us shortly confirming your offers.
# \n\n
#   Is there anything else I can help you with today?"
#
#   utter_cancellation_info:
#   - text: "To view our cancellation Policy or to find out how to cancel please visit :
#   https://www.royalcaribbean.com/gbr/en/faq/topics/reservation-payment-cancellation-policy
#   "
# Out:
# Overwriting domain.yml

# %%
# Train a ML model
model_path = rasa.train(domain, config, [training_files], output)
print(model_path)
# Out:
# The configuration for policies and pipeline was chosen automatically. It was written into the config file at 'config.yml'.
# /usr/local/lib/python3.10/dist-packages/rasa/utils/tensorflow/model_data.py:774: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   np.concatenate(np.array(f)),
# ...
# Processed trackers: 100%|██████████| 362/362 [00:11<00:00, 32.22it/s, # action=4654]
# Processed actions: 4654it [00:08, 541.38it/s, # examples=4654]
# Processed trackers: 100%|██████████| 2/2 [00:00<00:00, 163.43it/s, # action=5]
# Processed actions: 5it [00:00, 953.51it/s, # examples=4]
# ...
# Processed trackers: 100%|██████████| 862/862 [00:02<00:00, 302.95it/s, # action=454]
# ...

# %%
from rasa.jupyter import chat
#endpoints = 'endpoints.yml'

endpoints = None

# %%
# Chat with SunShine#

chat(model_path.model, endpoints)

endpoints = None
# Out:
# WARNING:rasa.shared.utils.common:The UnexpecTED Intent Policy is currently experimental and might change or be removed in the future 🔬 Please share your feedback on it in the forum (https://forum.rasa.com) to help us make this feature ready for production.
# Your bot is ready to talk! Type your messages here or send '/stop'.
# Hello
# Hello! Welcome to Royal Caribbean!
#  My name is SunShine, how may I assist you today?
# I want to go on a cruise
# Amazing, lets get you started! Firstly, where would you like to go?
#  Here are some of our popular destinations:
#  Europe:
#  1) France
#  2) Norway
#  3) Croatia
#  4) Greece
#
# Asia:
#  1) Thailand
#  2) China
#  3) Japan
#
# North America:
#  1) Florida
#  2) Hawaii
#  3) Canada
#
# Or go to the following link to see the full list of our destinations: https://www.royalcaribbean.com/gbr/en/cruise-destinations?
# I want to go to Hawaii
# Amazing, and how long do you want to travel for? You can pick from the following:
# 1 week
# ...

# %%
# Evaluate your model against test data#
# Rasa has a convenience function for getting your training data.
# Rasa's get_core_directory and get_nlu_directory are functions which recursively find all the stories or NLU data files and
# copies them into temporary directories.
# The return values are the paths to these newly created directories.

import rasa.shared.data as data
nlu_data_directory = data.get_nlu_directory(training_files)
stories_directory = data.get_core_directory(training_files)
print(stories_directory, nlu_data_directory)
rasa.test(model_path, stories_directory, nlu_data_directory)
print("Done testing.")
# Out:
# /tmp/tmpicj6v457 /tmp/tmpk6pnms28
# Done testing.
